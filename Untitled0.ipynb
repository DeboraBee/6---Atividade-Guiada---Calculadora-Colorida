# %% [markdown]
# <a href="https://colab.research.google.com/github/DeboraBee/6---Atividade-Guiada---Calculadora-Colorida/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = ("Debora")
idade = ("23")
cidade = ("São Paulo")
print(f"Oi, {nome}, você tem {idade} e mora em {cidade}")
# Out:
# Oi, Debora, você tem 23 e mora em São Paulo

# %%
#função que recebe do usuário informações do teclado
nome2 = input("Olá, qual o seu nome?")
idade1 = int(input("Qual a sua idade?"))
print(nome2)
print(idade1)
# Out:
# Olá, qual o seu nome?Debora
# Qual a sua idade?23
# Debora
# 23

# %%
# variaveis globais do sistema
alunos = ["Rafeal","Jessica","Erick","Taynara","Rafael P"]

# exibibir os dados da lista
print(alunos)
# exibir um item da lista - chama a lista e seu index  list[index]
print(alunos[-1])
# os index sao as posições dos elementos
# começando em 0 e indo ao infinito
# importante, podemos usar os valor -1 para ultimo
# -2 para penultimo
# -3 antepenultimo e assim por diante
